# %% [markdown]
# # Problem Set 2
#
# ## For this assignment, submit Python code to create, fit, and evaluate your final, best model for predicting fuel efficiency.
#
# The code you submit should at the minimum have these peices:
# * load the data
# * select (and create, if needed) the predictor variables for the model
# * create and fit the linear model
# * print model evaluation information, which must include, at a minimum R2

# %%
# Step 1: load the data 
import pandas as pd
df = pd.read_csv('Data/auto_mpg.csv') # note I am reading this data in from my data folder in the GitHub Repository
#df = pd.read_csv('/blue/zoo6927/share/Jupyter_Content/data/auto_mpg.csv') # Use this script if running on HyperGator Server
df # print data frame to make sure it looks okay
# Out:
#       mpg  cyl   disp   hp  weight  accel  year  origin  \
# 0    18.0    8  307.0  130    3504   12.0    70       1
# 1    15.0    8  350.0  165    3693   11.5    70       1
# 2    18.0    8  318.0  150    3436   11.0    70       1
# 3    16.0    8  304.0  150    3433   12.0    70       1
# 4    17.0    8  302.0  140    3449   10.5    70       1
# ..    ...  ...    ...  ...     ...    ...   ...     ...
# 393  27.0    4  140.0   86    2790   15.6    82       1
# 394  44.0    4   97.0   52    2130   24.6    82       2
# 395  32.0    4  135.0   84    2295   11.6    82       1
# 396  28.0    4  120.0   79    2625   18.6    82       1
# 397  31.0    4  119.0   82    2720   19.4    82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# Step 2: Select the predictor variables for the model 

x = df[['cyl','disp','weight','accel']] #selected 6 variables
y = df[['mpg']]

print(x)
print(y)
# Out:
#      cyl   disp   hp  weight
# 0      8  307.0  130    3504
# 1      8  350.0  165    3693
# 2      8  318.0  150    3436
# 3      8  304.0  150    3433
# 4      8  302.0  140    3449
# ..   ...    ...  ...     ...
# 393    4  140.0   86    2790
# 394    4   97.0   52    2130
# 395    4  135.0   84    2295
# 396    4  120.0   79    2625
# 397    4  119.0   82    2720
#
# [398 rows x 4 columns]
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
# Step 3 Create and fit the linear model
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(x,y)

print(model.intercept_, model.coef_) # print model coef
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-5aa5c7d02df9> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3
# ----> 4 model = LinearRegression().fit(x,y)
#       5
#       6 print(model.intercept_, model.coef_) # print model coef
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     819                     ensure_min_samples=ensure_min_samples,
#     820                     ensure_min_features=ensure_min_features,
# --> 821                     estimator=estimator)
#     822     if multi_output:
#     823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1896
#    1897     def __array__(self, dtype=None) -> np.ndarray:
# -> 1898         return np.asarray(self._values, dtype=dtype)
#    1899
#    1900     def __array_wrap__(
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: '?'

# %%
# Step 4 print model evaluation information: R2 & MSE
import numpy as np

# First write function to return MSE
def mse(model, x, y):
    return np.mean((y - model.predict(x))**2)


print("MSE is", mse(model, x, y))
print("R2 is", model.score(x,y))
